# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import numpy as np
asset = pd.read_csv(r"D:/Git/Algo_trading/reports/asset_performance_leaderboard.csv")
global_summary = pd.read_csv(r"D:/Git/Algo_trading/reports/global_strategy_summary.csv")

# %%
global_summary
# Out:
#                     Strategy  Avg_Return_Per_Asset_pct  Median_Return_pct  \
# 0                Momentum_20                     31.65               2.71
# 1               Trend_Filter                      6.15             -15.62
# 2               Volume_Spike                      8.23               4.50
# 3            Turtle_Breakout                     11.86               3.28
# 4       EMA21_Mean_Reversion                     -3.07              -2.32
# 5    MACD_Histogram_Momentum                      6.81               3.64
# 6        Volatility_Breakout                      6.67               2.17
# 7   Bollinger_Mean_Reversion                      3.44               1.98
# 8             Support_Bounce                      6.21               5.82
# 9              EMA_Crossover                      5.04               3.63
# 10            RSI_Overbought                     -2.02              -1.36
# 11              RSI_Oversold                      3.34               2.56
# ...

# %%
asset.head(100)
# Out:
#         Ticker              Strategy  Total_Return_%  Trades  Win_Rate_%  \
# 0      MAZDOCK           Momentum_20          877.49     716       52.09
# 1      MAZDOCK          Trend_Filter          820.78    1038       51.54
# 2   COCHINSHIP          Trend_Filter          739.53    1038       51.16
# 3         FACT           Momentum_20          697.86     725       51.45
# 4          BSE           Momentum_20          580.33     757       54.69
# 5       SUZLON           Momentum_20          538.71     778       50.51
# 6       ZENTEC           Momentum_20          523.37     662       48.79
# 7         IFCI           Momentum_20          496.58     793       49.05
# 8         RVNL           Momentum_20          475.21     685       51.53
# 9   COCHINSHIP           Momentum_20          470.49     752       50.80
# 10        IRFC          Trend_Filter          465.31    1038       49.13
# 11       TARIL           Momentum_20          450.65     741       52.90
# ...

# %%
# Out:
#                     Strategy  Avg_Return_Per_Asset_pct  Median_Return_pct  \
# 0                Momentum_20                     31.65               2.71
# 1               Trend_Filter                      6.15             -15.62
# 2               Volume_Spike                      8.23               4.50
# 3            Turtle_Breakout                     11.86               3.28
# 4       EMA21_Mean_Reversion                     -3.07              -2.32
# 5    MACD_Histogram_Momentum                      6.81               3.64
# 6        Volatility_Breakout                      6.67               2.17
# 7   Bollinger_Mean_Reversion                      3.44               1.98
# 8             Support_Bounce                      6.21               5.82
# 9              EMA_Crossover                      5.04               3.63
# 10            RSI_Overbought                     -2.02              -1.36
# 11              RSI_Oversold                      3.34               2.56
# ...
